# %%
# !pip install requests==2.32.3 geopandas==1.0.1
# import requests
# import geopandas as gpd
# print(requests.__version__)
# print(gpd.__version__)
# Out:
# 2.32.3
# 1.0.1

# %%
import requests
import geopandas as gpd
from shapely.geometry import Point

# %% [markdown]
# # OSM amenity
# - https://wiki.openstreetmap.org/wiki/Key:amenity
# - https://wiki.openstreetmap.org/wiki/Key:shop
# - 전체적인 tag 확인
#   - https://taginfo.openstreetmap.org/keys/highway#values
#   - https://wiki.openstreetmap.org/wiki/Ko:%ED%83%9C%EA%B7%B8
#
# ## ✅ OSM에서 자주 쓰이는 주요 Key 목록
#
# ### 1️⃣ **장소 및 시설 관련 (`amenity`, `shop`, `office` 등)**
#
# | Key | 설명 | 예시 |
# | --- | --- | --- |
# | `amenity` | 공공시설 및 편의시설 | `amenity=restaurant` (음식점) |
# | `shop` | 상점 및 가게 | `shop=convenience` (편의점) |
# | `office` | 사무실 유형 | `office=it` (IT 회사) |
# | `tourism` | 관광 관련 시설 | `tourism=hotel` (호텔) |
#
# ---
#
# ### 2️⃣ **교통 및 도로 (`highway`, `railway`, `public_transport` 등)**
#
# | Key | 설명 | 예시 |
# | --- | --- | --- |
# | `highway` | 도로 유형 | `highway=motorway` (고속도로) |
# | `railway` | 철도 및 지하철 | `railway=subway` (지하철) |
# | `public_transport` | 대중교통 시설 | `public_transport=station` (기차역, 지하철역) |
# | `aeroway` | 공항 관련 시설 | `aeroway=runway` (활주로) |
#
# ---
#
# ### 3️⃣ **건물 및 주소 (`building`, `addr:*` 등)**
#
# | Key | 설명 | 예시 |
# | --- | --- | --- |
# | `building` | 건물 유형 | `building=apartments` (아파트) |
# | `addr:housenumber` | 건물 번호 | `addr:housenumber=123` |
# | `addr:street` | 도로명 주소 | `addr:street=Gangnam-daero` |
# | `addr:city` | 도시명 | `addr:city=Seoul` |
#
# ---
#
# ### 4️⃣ **지형 및 자연 (`natural`, `landuse`, `waterway` 등)**
#
# | Key | 설명 | 예시 |
# | --- | --- | --- |
# | `natural` | 자연 지형 | `natural=tree` (나무) |
# | `landuse` | 토지 이용 목적 | `landuse=residential` (주거 지역) |
# | `waterway` | 수로 및 하천 | `waterway=river` (강) |
#
# ---
#
# ### 5️⃣ **기타 유용한 태그**
#
# | Key | 설명 | 예시 |
# | --- | --- | --- |
# | `name` | 이름 | `name=GS25 강남역점` |
# | `brand` | 브랜드명 | `brand=7-Eleven` |
# | `operator` | 운영 주체 | `operator=BGF Retail` |
# | `opening_hours` | 영업 시간 | `opening_hours=24/7` |
# | `website` | 공식 웹사이트 | `website=https://www.7-eleven.co.kr/` |
# | `phone` | 전화번호 | `phone=+82-2-1234-5678` |

# %% [markdown]
# ## 공공시설 및 편의시설, 지하철, 상점/가게

# %% [markdown]
# ### 공공시설

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["amenity"](area.searchArea);
);
out body;
"""
# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data['elements'][13]


pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', tags.get("name.ko", tags.get('description', tags.get('name:en', None)))),
            'item': tags.get('amenity', None),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['name', 'item' ,'lon', 'lat','geometry'])
pois_gdf
# Out:
#                     name              item         lon        lat  \
# 0            AnAm Church  place_of_worship  127.022408  37.589374
# 1                   None           parking  126.897876  37.556702
# 2       답십리삼거리;퀸덤코인노래연습장       karaoke_box  127.055024  37.565182
# 3                   kill              cafe  127.012210  37.591050
# 4                    샐위치              cafe  127.070900  37.565720
# ...                  ...               ...         ...        ...
# 112400              None       post_office  126.938342  37.563838
# 112401              None               atm  126.938376  37.563783
# 112402              None               atm  126.938329  37.563792
# 112403              맥도날드         fast_food  126.893462  37.530916
# 112404       Slow Stream              cafe  127.015319  37.574715
#
#                           geometry
# 0       POINT (127.02241 37.58937)
# 1        POINT (126.89788 37.5567)
# 2       POINT (127.05502 37.56518)
# 3       POINT (127.01221 37.59105)
# 4        POINT (127.0709 37.56572)
# ...                            ...
# 112400  POINT (126.93834 37.56384)
# 112401  POINT (126.93838 37.56378)
# 112402  POINT (126.93833 37.56379)
# 112403  POINT (126.89346 37.53092)
# 112404  POINT (127.01532 37.57471)
#
# [112405 rows x 5 columns]

# %% [markdown]
# ### 대중교통 지하철

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["public_transport"]["subway"="yes"]["public_transport"="station"](area.searchArea);
  node["highway"="bus_stop"](area.searchArea);
);
out body;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'item': tags.get('station', tags.get('highway', None)),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf_trans = gpd.GeoDataFrame(pois, columns=['name', 'item' ,'lon', 'lat','geometry'])
pois_gdf_trans
# Out:
#                     name      item         lon        lat  \
# 0                  한성대입구    subway  127.005962  37.588514
# 1                    제기동    subway  127.034467  37.578378
# 2                    신이문    subway  127.067290  37.601638
# 3                     회기    subway  127.057624  37.589497
# 4                     월계    subway  127.058865  37.633063
# ...                  ...       ...         ...        ...
# 9774  경의선숲길공원(홍대입구역3번출구)  bus_stop  126.925393  37.558479
# 9775        경의선숲길공원(연남동)  bus_stop  126.921370  37.563340
# 9776             항동생활체육관  bus_stop  126.822656  37.477343
# 9777            한양수자인아파트  bus_stop  126.824657  37.477930
# 9778        항동하버라인3단지아파트  bus_stop  126.825502  37.479617
#
#                         geometry
# 0     POINT (127.00596 37.58851)
# 1     POINT (127.03447 37.57838)
# 2     POINT (127.06729 37.60164)
# 3      POINT (127.05762 37.5895)
# 4     POINT (127.05887 37.63306)
# ...                          ...
# 9774  POINT (126.92539 37.55848)
# 9775  POINT (126.92137 37.56334)
# 9776  POINT (126.82266 37.47734)
# 9777  POINT (126.82466 37.47793)
# 9778   POINT (126.8255 37.47962)
#
# [9779 rows x 5 columns]

# %% [markdown]
# ### Shop

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["shop"](area.searchArea);
  way["shop"](area.searchArea);
  relation["shop"](area.searchArea);
);
out center;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'item': f"shop_{tags.get('shop', None)}",
            'lon' : lon,
            'lat' : lat
        })

pois_gdf_shop = gpd.GeoDataFrame(pois, columns=['name', 'item' ,'lon', 'lat','geometry'])
pois_gdf_shop
# Out:
#        name              item         lon        lat  \
# 0        필샵      shop_bicycle  127.082209  37.561630
# 1      한강문고        shop_books  126.906845  37.559409
# 2     세븐일레븐  shop_convenience  126.878490  37.509110
# 3     다비치안경     shop_optician  126.995283  37.485529
# 4     하나로마트  shop_supermarket  127.105612  37.601073
# ...     ...               ...         ...        ...
# 7760   GS25  shop_convenience  127.128989  37.524581
# 7761  이마트24  shop_convenience  127.129970  37.526806
# 7762   뚜레쥬르       shop_bakery  127.127515  37.509859
# 7763  Honda   shop_motorcycle  127.111069  37.501414
# 7764   None        shop_books  126.938391  37.563831
#
#                         geometry
# 0     POINT (127.08221 37.56163)
# 1     POINT (126.90684 37.55941)
# 2     POINT (126.87849 37.50911)
# 3     POINT (126.99528 37.48553)
# 4     POINT (127.10561 37.60107)
# ...                          ...
# 7760  POINT (127.12899 37.52458)
# 7761  POINT (127.12997 37.52681)
# 7762  POINT (127.12752 37.50986)
# 7763  POINT (127.11107 37.50141)
# 7764  POINT (126.93839 37.56383)
#
# [7765 rows x 5 columns]

# %%
print(len(pois_gdf), len(pois_gdf_trans), len(pois_gdf_shop))
pois_gdf_dropna=pois_gdf.dropna(subset=['name'], inplace=False)
pois_gdf_trans_dropna=pois_gdf_trans.dropna(subset=['name'], inplace=False)
pois_gdf_shop_dropna=pois_gdf_shop.dropna(subset=['name'], inplace=False)
print(len(pois_gdf_dropna), len(pois_gdf_trans_dropna), len(pois_gdf_shop_dropna))
print("Total data length : ",len(pois_gdf_dropna)+ len(pois_gdf_trans_dropna)+ len(pois_gdf_shop_dropna))
# Out:
# 112405 9779 7765
# 108333 9715 7200
# Total data length :  125248

# %%
df_poi=pd.concat([pois_gdf_dropna, pois_gdf_trans_dropna, pois_gdf_shop_dropna], axis=0)
df_poi
# Out:
#                   name              item         lon        lat  \
# 0          AnAm Church  place_of_worship  127.022408  37.589374
# 2     답십리삼거리;퀸덤코인노래연습장       karaoke_box  127.055024  37.565182
# 3                 kill              cafe  127.012210  37.591050
# 4                  샐위치              cafe  127.070900  37.565720
# 5                 극동방송            studio  126.923429  37.549439
# ...                ...               ...         ...        ...
# 7758        gs25 개포미래점  shop_convenience  127.049185  37.478841
# 7760              GS25  shop_convenience  127.128989  37.524581
# 7761             이마트24  shop_convenience  127.129970  37.526806
# 7762              뚜레쥬르       shop_bakery  127.127515  37.509859
# 7763             Honda   shop_motorcycle  127.111069  37.501414
#
#                         geometry
# 0     POINT (127.02241 37.58937)
# 2     POINT (127.05502 37.56518)
# 3     POINT (127.01221 37.59105)
# 4      POINT (127.0709 37.56572)
# 5     POINT (126.92343 37.54944)
# ...                          ...
# 7758  POINT (127.04919 37.47884)
# 7760  POINT (127.12899 37.52458)
# 7761  POINT (127.12997 37.52681)
# 7762  POINT (127.12752 37.50986)
# 7763  POINT (127.11107 37.50141)
#
# [125248 rows x 5 columns]

# %% [markdown]
# ### 데이터 저장

# %%
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine
import geopandas as gpd

import os
from dotenv import load_dotenv

# .env 파일 로드
load_dotenv()

hostname = os.getenv('db_hostname')
username = os.getenv('db_username')
password = os.getenv('db_password')
port = os.getenv('db_port')
database= os.getenv('database')

connect_url = f"postgresql://{username}:{password}@{hostname}:{port}/{database}"
engine = create_engine(connect_url)

# 데이터베이스 저장
poi_gdf=gpd.GeoDataFrame(df_poi, geometry = 'geometry')
poi_gdf = poi_gdf.set_crs('EPSG:4326', allow_override=True) # epsg 4326
# gdf_sgg_4326=emd_cell_crs.to_crs(epsg=4326)
poi_gdf.to_postgis(name='tb_poi', con=engine, if_exists='replace')

# 파일로 저장
poi_gdf.to_file("tb_poi.geojson", driver='GeoJSON')
poi_gdf.to_csv("tb_poi.csv", index=False)
pd.DataFrame(df_poi.item.value_counts()).to_csv("poi_items.csv")
# Out:
# postgresql://postgres:dtonic@localhost:5433/postgres

# %% [markdown]
# # 검토 - 각 key:tag 별 데이터 확인용

# %% [markdown]
# ### 버스정류장

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["highway"="bus_stop"](area.searchArea);
  way["highway"="bus_stop"](area.searchArea);
  relation["highway"="bus_stop"](area.searchArea);
  
  node["amenity"="bus_station"](area.searchArea);
  way["amenity"="bus_station"](area.searchArea); 
  
  // 음식점, 카페 등등
  node["amenity"="restaurant"](area.searchArea);
  way["amenity"="restaurant"](area.searchArea);
  relation["amenity"="restaurant"](area.searchArea);
  
  node["amenity"="fast_food"](area.searchArea);
  way["amenity"="fast_food"](area.searchArea);
  relation["amenity"="fast_food"](area.searchArea);
  
  node["amenity"="cafe"](area.searchArea);
  way["amenity"="cafe"](area.searchArea);
  relation["amenity"="cafe"](area.searchArea);
  
  node["amenity"="hospital"](area.searchArea);
  way["amenity"="hospital"](area.searchArea);
  relation["amenity"="hospital"](area.searchArea);

  node["amenity"="dentist"](area.searchArea);
  way["amenity"="dentist"](area.searchArea);
  relation["amenity"="dentist"](area.searchArea);
  
  node["amenity"="clinic"](area.searchArea);
  way["amenity"="clinic"](area.searchArea);
  relation["amenity"="clinic"](area.searchArea);

  node["amenity"="doctors"](area.searchArea);
  way["amenity"="doctors"](area.searchArea);
  relation["amenity"="doctors"](area.searchArea);

  node["amenity"="pharmacy"](area.searchArea);
  way["amenity"="pharmacy"](area.searchArea);
  relation["amenity"="pharmacy"](area.searchArea);

  node["amenity"="veterinary"](area.searchArea);
  way["amenity"="veterinary"](area.searchArea);
  relation["amenity"="veterinary"](area.searchArea);

  node["amenity"="college"](area.searchArea);
  way["amenity"="college"](area.searchArea);
  relation["amenity"="college"](area.searchArea);
  
  node["amenity"="school"](area.searchArea);
  way["amenity"="school"](area.searchArea);
  relation["amenity"="school"](area.searchArea);
  
  node["amenity"="university"](area.searchArea);
  way["amenity"="university"](area.searchArea);
  relation["amenity"="university"](area.searchArea);
);
out body;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
print(response)
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'amenity': tags.get('amenity', tags.get('highway', None)),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['geometry', 'name', 'amenity', 'lon', 'lat'])
pois_gdf
# Out:
# <Response [200]>
#                          geometry           name     amenity         lon  \
# 0      POINT (127.06401 37.50793)            삼성역    bus_stop  127.064010
# 1      POINT (127.06365 37.50724)            삼성역    bus_stop  127.063652
# 2       POINT (126.9911 37.55109)     남산서울타워(04)    bus_stop  126.991096
# 3      POINT (126.98341 37.55456)     남산산책로입구B코스    bus_stop  126.983410
# 4      POINT (126.98747 37.55859)  서울애니메이션센터숭의여대    bus_stop  126.987470
# ...                           ...            ...         ...         ...
# 94184  POINT (127.12959 37.52513)        God Eat  restaurant  127.129595
# 94185  POINT (127.12949 37.52492)         Allavo  restaurant  127.129493
# 94186  POINT (126.96579 37.52956)       Plantude  restaurant  126.965787
# 94187   POINT (126.97911 37.5655)             담솥  restaurant  126.979108
# 94188  POINT (126.93831 37.56331)        맛나샘 학식당  restaurant  126.938311
#
#              lat
# 0      37.507930
# 1      37.507243
# 2      37.551092
# 3      37.554560
# 4      37.558590
# ...          ...
# 94184  37.525131
# 94185  37.524923
# 94186  37.529562
# 94187  37.565499
# 94188  37.563313
#
# [94189 rows x 5 columns]

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["highway"="*"](area.searchArea);
  way["highway"="bus_stop"](area.searchArea);
  relation["highway"="bus_stop"](area.searchArea);
  
  node["amenity"="bus_station"](area.searchArea);
  way["amenity"="bus_station"](area.searchArea); 
);
out body;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'amenity': tags.get('amenity', tags.get('highway', None)),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['geometry', 'name', 'amenity', 'lon', 'lat'])
pois_gdf

# %% [markdown]
# ### restaurant

# %%
### 음식점
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["amenity"="restaurant"](area.searchArea);
  way["amenity"="restaurant"](area.searchArea);
  relation["amenity"="restaurant"](area.searchArea);
);
out body;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'amenity': tags.get('amenity', tags.get('highway', None)),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['geometry', 'name', 'amenity', 'lon', 'lat'])
pois_gdf
# Out:
#                          geometry      name     amenity         lon        lat
# 0       POINT (127.0242 37.57627)     아재순대국  restaurant  127.024196  37.576270
# 1      POINT (126.88779 37.52211)      바다공원  restaurant  126.887794  37.522106
# 2      POINT (126.97298 37.55826)     동강나루터  restaurant  126.972977  37.558260
# 3      POINT (127.14744 37.54918)      None  restaurant  127.147441  37.549179
# 4        POINT (127.034 37.51939)      선창회집  restaurant  127.033998  37.519389
# ...                           ...       ...         ...         ...        ...
# 82574  POINT (127.12959 37.52513)   God Eat  restaurant  127.129595  37.525131
# 82575  POINT (127.12949 37.52492)    Allavo  restaurant  127.129493  37.524923
# 82576  POINT (126.96579 37.52956)  Plantude  restaurant  126.965787  37.529562
# 82577   POINT (126.97911 37.5655)        담솥  restaurant  126.979108  37.565499
# 82578  POINT (126.93831 37.56331)   맛나샘 학식당  restaurant  126.938311  37.563313
#
# [82579 rows x 5 columns]

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["railway"="station"](area.searchArea);
  node["railway"="subway_entrance"](area.searchArea);
);
out body;
"""
# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

# %% [markdown]
# ### 병원, 클리닉, 치과, 약국 등

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json][timeout:900];
area(3602297418)->.searchArea;  // 서울의 Area ID
node(area.searchArea);
out body 100000;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'amenity': tags.get('amenity', tags.get('highway', None)),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['geometry', 'name', 'amenity', 'lon', 'lat'])
pois_gdf
# Out:
#                          geometry              name          amenity  \
# 0      POINT (127.02953 37.58266)            안암 오거리             None
# 1      POINT (127.07283 37.58511)            겸재교 서편             None
# 2      POINT (127.07766 37.57192)            장평교 서편             None
# 3       POINT (127.07664 37.5805)            장안교 서편             None
# 4      POINT (127.05137 37.55615)  중랑천-청계천 자전거길 교차로             None
# ...                           ...               ...              ...
# 12967  POINT (127.03796 37.56114)              None         crossing
# 12968  POINT (126.85835 37.49096)              None         crossing
# 12969   POINT (126.86043 37.4924)              None         crossing
# 12970  POINT (126.86127 37.49049)              None  traffic_signals
# 12971  POINT (126.96907 37.56248)           동북아역사재단             None
#
#               lon        lat
# 0      127.029529  37.582658
# 1      127.072834  37.585108
# 2      127.077660  37.571917
# 3      127.076645  37.580495
# 4      127.051372  37.556149
# ...           ...        ...
# 12967  127.037957  37.561137
# 12968  126.858352  37.490960
# 12969  126.860427  37.492404
# 12970  126.861268  37.490485
# 12971  126.969067  37.562476
#
# [12972 rows x 5 columns]

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["amenity"="hospital"](area.searchArea);
  way["amenity"="hospital"](area.searchArea);
  relation["amenity"="hospital"](area.searchArea);

  node["amenity"="dentist"](area.searchArea);
  way["amenity"="dentist"](area.searchArea);
  relation["amenity"="dentist"](area.searchArea);
  
  node["amenity"="clinic"](area.searchArea);
  way["amenity"="clinic"](area.searchArea);
  relation["amenity"="clinic"](area.searchArea);

  node["amenity"="doctors"](area.searchArea);
  way["amenity"="doctors"](area.searchArea);
  relation["amenity"="doctors"](area.searchArea);

  node["amenity"="pharmacy"](area.searchArea);
  way["amenity"="pharmacy"](area.searchArea);
  relation["amenity"="pharmacy"](area.searchArea);

  node["amenity"="veterinary"](area.searchArea);
  way["amenity"="veterinary"](area.searchArea);
  relation["amenity"="veterinary"](area.searchArea);

);
out body;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'amenity': tags.get('amenity', tags.get('highway', None)),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['geometry', 'name', 'amenity', 'lon', 'lat'])
pois_gdf
# Out:
#                         geometry            name   amenity         lon  \
# 0      POINT (127.06098 37.5078)         가톨릭치과병원   dentist  127.060980
# 1      POINT (127.0404 37.52287)      에스플란트 치과병원   dentist  127.040400
# 2     POINT (127.12803 37.53759)        강동미즈여성병원  hospital  127.128029
# 3     POINT (127.12664 37.53726)  365mc비만클리닉 천호점   doctors  127.126641
# 4      POINT (127.1344 37.49798)         서울M치과의원   dentist  127.134398
# ...                          ...             ...       ...         ...
# 1819  POINT (126.93133 37.56292)           광혜약국1  pharmacy  126.931331
# 1820  POINT (127.04686 37.65205)         종로프라자약국  pharmacy  127.046856
# 1821  POINT (127.03839 37.52356)         닥터손유나의원    clinic  127.038395
# 1822   POINT (127.0476 37.47879)            기쁨약국  pharmacy  127.047596
# 1823  POINT (127.04787 37.47893)         행복온누리약국  pharmacy  127.047871
#
#             lat
# 0     37.507800
# 1     37.522870
# 2     37.537593
# 3     37.537259
# 4     37.497977
# ...         ...
# 1819  37.562923
# 1820  37.652055
# 1821  37.523562
# 1822  37.478788
# 1823  37.478933
#
# [1824 rows x 5 columns]

# %% [markdown]
# ### 학교

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea;  // 서울의 Area ID
(
  node["amenity"="college"](area.searchArea);
  way["amenity"="college"](area.searchArea);
  relation["amenity"="college"](area.searchArea);
  
  node["amenity"="school"](area.searchArea);
  way["amenity"="school"](area.searchArea);
  relation["amenity"="school"](area.searchArea);
  
  node["amenity"="university"](area.searchArea);
  way["amenity"="university"](area.searchArea);
  relation["amenity"="university"](area.searchArea);
);
out body;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            # 'highway': tags.get('highway', None),
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'amenity': tags.get('amenity', tags.get('highway', None)),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['geometry', 'name', 'amenity', 'lon', 'lat'])
pois_gdf
# Out:
#                        geometry         name     amenity         lon  \
# 0    POINT (126.91282 37.61925)     선일여자고등학교      school  126.912821
# 1    POINT (126.90988 37.62308)     서울대성고등학교      school  126.909884
# 2    POINT (127.16092 37.55005)     서울강동고등학교      school  127.160922
# 3    POINT (127.02465 37.62089)   성암국제무역고등학교      school  127.024648
# 4    POINT (126.91933 37.51138)       장훈고등학교      school  126.919326
# ..                          ...          ...         ...         ...
# 328  POINT (126.93762 37.56462)  연세대학교 산학협력단  university  126.937621
# 329  POINT (126.93682 37.56468)      법학전문대학원  university  126.936820
# 330  POINT (126.93667 37.56575)      연합신학대학원  university  126.936666
# 331  POINT (126.93675 37.56608)      대학원학생회관  university  126.936746
# 332  POINT (126.93915 37.56724)        행정대학원  university  126.939147
#
#            lat
# 0    37.619252
# 1    37.623075
# 2    37.550055
# 3    37.620888
# 4    37.511377
# ..         ...
# 328  37.564624
# 329  37.564682
# 330  37.565751
# 331  37.566084
# 332  37.567235
#
# [333 rows x 5 columns]

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea; 
// 시설 검색
(
  node["amenity"="atm"](area.searchArea);
  way["amenity"="atm"](area.searchArea);
  relation["amenity"="atm"](area.searchArea);
  
  node["amenity"="bank"](area.searchArea);
  way["amenity"="bank"](area.searchArea);
  relation["amenity"="bank"](area.searchArea);
);
// 결과 출력
out body;

"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
data

pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', None),
            'amenity': tags.get('amenity', None),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['geometry', 'name', 'amenity', 'lon', 'lat'])
pois_gdf
# Out:
#                         geometry      name amenity         lon        lat
# 0      POINT (127.04346 37.4709)      영동농협    bank  127.043463  37.470903
# 1     POINT (127.09575 37.54078)      중앙농협    bank  127.095750  37.540775
# 2      POINT (127.0807 37.53197)      중앙농협    bank  127.080705  37.531972
# 3     POINT (127.12737 37.54011)      강동농협    bank  127.127366  37.540111
# 4      POINT (127.0159 37.59337)      None    bank  127.015898  37.593368
# ...                          ...       ...     ...         ...        ...
# 1254  POINT (126.94002 37.56096)      None     atm  126.940025  37.560960
# 1255  POINT (126.83722 37.55466)        농협    bank  126.837225  37.554659
# 1256  POINT (127.04783 37.47881)  우리은행 ATM    bank  127.047825  37.478813
# 1257  POINT (126.93838 37.56378)      None     atm  126.938376  37.563783
# 1258  POINT (126.93833 37.56379)      None     atm  126.938329  37.563792
#
# [1259 rows x 5 columns]

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.5 1bd436f1',
#  'osm3s': {'timestamp_osm_base': '2025-03-20T08:36:10Z',
#   'timestamp_areas_base': '2025-02-06T02:17:44Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 368638763,
#    'lat': 37.470903,
#    'lon': 127.043463,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영동농협',
#     'name:en': 'Yeongdong Nonghyup',
#     'name:ko': '영동농협',
#     'name:ko-Latn': 'Yeongdongnonghyeop'}},
#   {'type': 'node',
#    'id': 368638768,
#    'lat': 37.540775,
#    'lon': 127.09575,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '중앙농협',
#     'name:en': 'Jungang Nonghyup',
#     'name:ko': '중앙농협',
#     'name:ko-Latn': 'Jungangnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638779,
#    'lat': 37.531972,
#    'lon': 127.080705,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '중앙농협',
#     'name:en': 'Jungang Nonghyup',
#     'name:ko': '중앙농협',
#     'name:ko-Latn': 'Jungangnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 368638782,
#    'lat': 37.540111,
#    'lon': 127.127366,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '강동농협',
#     'name:en': 'Gangdong Nonghyup',
#     'name:ja': '江東農協',
#     'name:ko': '강동농협',
#     'name:ko-Latn': 'Gangdongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638794,
#    'lat': 37.593368,
#    'lon': 127.015898,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name:en': 'Seoul Nonghyup',
#     'name:ko': '서울농협',
#     'name:ko-Latn': 'Seoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638796,
#    'lat': 37.5772911,
#    'lon': 126.892915,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'drive_through': 'no',
#     'name': '서서울농협 상암지점',
#     'name:en': 'Seobu Nonghyup',
#     'name:ja': '西部農協',
#     'name:ko': '서서울농협 상암지점',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638810,
#    'lat': 37.605563,
#    'lon': 127.078895,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '화산농협',
#     'name:en': 'Hwasan Nonghyup',
#     'name:ko': '화산농협',
#     'name:ko-Latn': 'Hwasannonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638812,
#    'lat': 37.5076066,
#    'lon': 127.0890236,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'branch': '동잠실지점',
#     'brand': '중앙농협',
#     'name': '중앙농협 동잠실지점',
#     'name:en': 'Jungang Nonghyup',
#     'name:ko': '중앙농협 동잠실지점',
#     'name:ko-Latn': 'Jungangnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638823,
#    'lat': 37.4507362,
#    'lon': 126.9102081,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '관악농협',
#     'name:en': 'Gwanak Nonghyup',
#     'name:ko': '관악농협',
#     'name:ko-Latn': 'Gwanangnonghyeop'}},
#   {'type': 'node',
#    'id': 368638824,
#    'lat': 37.4711564,
#    'lon': 126.9335763,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '관악농협 신림지점',
#     'name:en': 'Gwanak National Agricultural Cooperative Federation Sillim Branch',
#     'name:ko': '관악농협 신림지점',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638830,
#    'lat': 37.4958402,
#    'lon': 127.0398613,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영동농협',
#     'name:en': 'Yeongdong Nonghyup',
#     'name:ko': '영동농협',
#     'name:ko-Latn': 'Yeongdongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638835,
#    'lat': 37.486795,
#    'lon': 126.929326,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '관악농협',
#     'name:en': 'Gwanak Nonghyup',
#     'name:ko': '관악농협',
#     'name:ko-Latn': 'Gwanangnonghyeop'}},
#   {'type': 'node',
#    'id': 368638840,
#    'lat': 37.509256,
#    'lon': 127.124931,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '송파농협',
#     'name:en': 'Songpa Nonghyup',
#     'name:ko': '송파농협',
#     'name:ko-Latn': 'Songpanonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638846,
#    'lat': 37.543584,
#    'lon': 126.873072,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '강서농협',
#     'name:en': 'Gangseo Nonghyup',
#     'name:ko': '강서농협',
#     'name:ko-Latn': 'Gangseononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638849,
#    'lat': 37.477207,
#    'lon': 126.963768,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '관악농협',
#     'name:en': 'Gwanak Nonghyup',
#     'name:ko': '관악농협',
#     'name:ko-Latn': 'Gwanangnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638855,
#    'lat': 37.4797354,
#    'lon': 127.0405732,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '남서울농협',
#     'name:en': 'Nam Seoul Nonghyup',
#     'name:ko': '남서울농협',
#     'name:ko-Latn': 'Namseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638857,
#    'lat': 37.668056,
#    'lon': 127.047052,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '북서울농협',
#     'name:en': 'Buk Seoul Nonghyup',
#     'name:ko': '북서울농협',
#     'name:ko-Latn': 'Bukseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638864,
#    'lat': 37.600864,
#    'lon': 127.106532,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '동서울농협',
#     'name:en': 'Dong Seoul Nonghyup',
#     'name:ko': '동서울농협',
#     'name:ko-Latn': 'Dongseoullonghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638868,
#    'lat': 37.5797693,
#    'lon': 127.0921757,
#    'tags': {'addr:city': '서울특별시',
#     'addr:district': '중랑구',
#     'addr:housenumber': '307',
#     'addr:street': '용마산로',
#     'amenity': 'bank',
#     'atm': 'yes',
#     'name': '동서울농협',
#     'name:en': 'Dong Seoul Nonghyup',
#     'name:ko': '동서울농협',
#     'name:ko-Latn': 'Dongseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638875,
#    'lat': 37.476269,
#    'lon': 126.977112,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '남서울농협',
#     'name:en': 'Nam Seoul Nonghyup',
#     'name:ja': '南ソウル農協',
#     'name:ko': '남서울농협',
#     'name:ko-Latn': 'Namseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638884,
#    'lat': 37.572375,
#    'lon': 127.014181,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '동서울농협',
#     'name:en': 'Dong Seoul Nonghyup',
#     'name:ja': '東ソウル農協',
#     'name:ko': '동서울농협',
#     'name:ko-Latn': 'Dongseoullonghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638893,
#    'lat': 37.530567,
#    'lon': 126.905109,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영등포농협',
#     'name:en': 'Yeongdeungpo Nonghyup',
#     'name:ko': '영등포농협',
#     'name:ko-Latn': 'Yeongdeungpononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638897,
#    'lat': 37.5363078,
#    'lon': 126.8961155,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영등포농협',
#     'name:en': 'Yeongdeungpo Nonghyup',
#     'name:ko': '영등포농협',
#     'name:ko-Latn': 'Yeongdeungpononghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638898,
#    'lat': 37.483955,
#    'lon': 127.012007,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '남서울농협',
#     'name:en': 'Nam Seoul Nonghyup',
#     'name:ko': '남서울농협',
#     'name:ko-Latn': 'Namseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638907,
#    'lat': 37.567587,
#    'lon': 127.056958,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '동서울농협',
#     'name:en': 'Dong Seoul Nonghyup',
#     'name:ko': '동서울농협',
#     'name:ko-Latn': 'Dongseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638916,
#    'lat': 37.6075225,
#    'lon': 127.0963563,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': 'NH농협은행',
#     'brand:en': 'NH Bank',
#     'brand:ko': 'NH농협은행',
#     'brand:wikidata': 'Q15283673',
#     'name': 'NH농협은행',
#     'name:en': 'NH Bank',
#     'name:ko': 'NH농협은행',
#     'name:ko-Latn': 'Dongseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638936,
#    'lat': 37.499882,
#    'lon': 126.887629,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영등포농협',
#     'name:en': 'Yeongdeungpo Nonghyup',
#     'name:ko': '영등포농협',
#     'name:ko-Latn': 'Yeongdeungpononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638948,
#    'lat': 37.6803928,
#    'lon': 127.0451212,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '북서울농협',
#     'name:en': 'Buk Seoul Nonghyup',
#     'name:ja': '北ソウル農協',
#     'name:ko': '북서울농협',
#     'name:ko-Latn': 'Bukseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638960,
#    'lat': 37.4845045,
#    'lon': 127.0354164,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '남서울농협',
#     'name:en': 'South Seoul Nonghyup',
#     'name:ja': '南ソウル農協',
#     'name:ko': '남서울농협',
#     'name:ko-Latn': 'Namseoullonghyeop'}},
#   {'type': 'node',
#    'id': 368638969,
#    'lat': 37.5897228,
#    'lon': 127.0927771,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '동서울농협',
#     'name:en': 'Dong Seoul Nonghyup',
#     'name:ko': '동서울농협',
#     'name:ko-Latn': 'Dongseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638980,
#    'lat': 37.510946,
#    'lon': 126.912567,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영등포농협',
#     'name:en': 'Yeongdeungpo Nonghyup',
#     'name:ko': '영등포농협',
#     'name:ko-Latn': 'Yeongdeungpononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638989,
#    'lat': 37.478594,
#    'lon': 126.890138,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영등포농협',
#     'name:en': 'Yeongdeungpo Nonghyup',
#     'name:ko': '영등포농협',
#     'name:ko-Latn': 'Yeongdeungpononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368638998,
#    'lat': 37.497658,
#    'lon': 126.951916,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영등포농협',
#     'name:en': 'Yeongdeungpo Nonghyup',
#     'name:ko': '영등포농협',
#     'name:ko-Latn': 'Yeongdeungpononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639010,
#    'lat': 37.510684,
#    'lon': 127.01868,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '남서울농협',
#     'name:en': 'Nam Seoul Nonghyup',
#     'name:ko': '남서울농협',
#     'name:ko-Latn': 'Namseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639023,
#    'lat': 37.5066437,
#    'lon': 126.8840513,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'branch': '영등포농협',
#     'brand': '농협',
#     'brand:ko': '농협',
#     'brand:wikidata': 'Q15283673',
#     'name': '농협',
#     'name:en': 'Nonghyup Bank',
#     'name:ko': '농협',
#     'name:ko-Latn': 'Nonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639033,
#    'lat': 37.638267,
#    'lon': 127.037256,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '북서울농협',
#     'name:en': 'Buk Seoul Nonghyup',
#     'name:ko': '북서울농협',
#     'name:ko-Latn': 'Bukseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639046,
#    'lat': 37.49447,
#    'lon': 127.017218,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '남서울농협',
#     'name:en': 'Nam Seoul Nonghyup',
#     'name:ja': '南ソウル 農協',
#     'name:ko': '남서울농협',
#     'name:ko-Latn': 'Namseoullonghyeop'}},
#   {'type': 'node',
#    'id': 368639056,
#    'lat': 37.519259,
#    'lon': 126.888847,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영등포농협',
#     'name:en': 'Yeongdeungpo Nonghyup',
#     'name:ko': '영등포농협',
#     'name:ko-Latn': 'Yeongdeungpononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639081,
#    'lat': 37.5007221,
#    'lon': 126.941389,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '영등포농협',
#     'name:en': 'Yeongdeungpo Nonghyup',
#     'name:ko': '영등포농협',
#     'name:ko-Latn': 'Yeongdeungpononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639103,
#    'lat': 37.65799,
#    'lon': 127.014027,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '북서울농협',
#     'name:en': 'Buk Seoul Nonghyup',
#     'name:ko': '북서울농협',
#     'name:ko-Latn': 'Bukseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639115,
#    'lat': 37.500386,
#    'lon': 126.909802,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양봉농협',
#     'name:en': 'Korea Yangbong Nonghyup',
#     'name:ko': '한국양봉농협',
#     'name:ko-Latn': 'Hangukyangbongnonghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639127,
#    'lat': 37.6122196,
#    'lon': 127.0780362,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울우유농협',
#     'name:en': 'Seoul Uyu Nonghyup',
#     'name:ko': '서울우유농협',
#     'name:ko-Latn': 'Seouluyunonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639139,
#    'lat': 37.549151,
#    'lon': 127.127465,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울우유농협',
#     'name:en': 'Seoul Uyu Nonghyup',
#     'name:ko': '서울우유농협',
#     'name:ko-Latn': 'Seouluyunonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639187,
#    'lat': 37.643096,
#    'lon': 127.021873,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울우유농협',
#     'name:en': 'Seoul Uyu Nonghyup',
#     'name:ko': '서울우유농협',
#     'name:ko-Latn': 'Seouluyunonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639200,
#    'lat': 37.499678,
#    'lon': 126.92101,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울우유농협',
#     'name:en': 'Seoul Uyu Nonghyup',
#     'name:ko': '서울우유농협',
#     'name:ko-Latn': 'Seouluyunonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639208,
#    'lat': 37.556409,
#    'lon': 127.011188,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양봉농협',
#     'name:en': 'Korea Yangbong Nonghyup',
#     'name:ko': '한국양봉농협',
#     'name:ko-Latn': 'Hangukyangbongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639220,
#    'lat': 37.490671,
#    'lon': 126.900952,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '관악단위농협',
#     'name:en': 'Gwanakdanwi Nonghyup',
#     'name:ko': '관악단위농협',
#     'name:ko-Latn': 'Gwanakdanwinonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639231,
#    'lat': 37.555582,
#    'lon': 126.909984,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울우유농협',
#     'name:en': 'Seoul Uyu Nonghyup',
#     'name:ko': '서울우유농협',
#     'name:ko-Latn': 'Seouluyunonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639244,
#    'lat': 37.601123,
#    'lon': 126.920613,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국화훼농협',
#     'name:en': 'Korea Hwahwe Nonghyup',
#     'name:ko': '한국화훼농협',
#     'name:ko-Latn': 'Hangukhwahwenonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639256,
#    'lat': 37.497624,
#    'lon': 127.147382,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '송파단위농협',
#     'name:en': 'Songpadanwi Nonghyup',
#     'name:ko': '송파단위농협',
#     'name:ko-Latn': 'Songpadanwinonghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639269,
#    'lat': 37.484224,
#    'lon': 126.95527,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양봉농협',
#     'name:en': 'Korea Yangbong Nonghyup',
#     'name:ko': '한국양봉농협',
#     'name:ko-Latn': 'Hangukyangbongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 368639278,
#    'lat': 37.5984492,
#    'lon': 127.0355954,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양봉농협',
#     'name:en': 'Korea Yangbong Nonghyup',
#     'name:ko': '한국양봉농협',
#     'name:ko-Latn': 'Hangukyangbongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639288,
#    'lat': 37.58714,
#    'lon': 126.91684,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울우유농협',
#     'name:en': 'Seoul Uyu Nonghyup',
#     'name:ko': '서울우유농협',
#     'name:ko-Latn': 'Seouluyunonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639297,
#    'lat': 37.5948339,
#    'lon': 127.0643841,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울경기양돈농협',
#     'name:en': 'Seoul Gyeonggiyangdon Nonghyup',
#     'name:ko': '서울경기양돈농협',
#     'name:ko-Latn': 'Seoulgyeonggiyangdonnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639316,
#    'lat': 37.598315,
#    'lon': 127.077365,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울경기양돈농협',
#     'name:en': 'Seoul Gyeonggiyangdon Nonghyup',
#     'name:ko': '서울경기양돈농협',
#     'name:ko-Latn': 'Seoulgyeonggiyangdonnonghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639328,
#    'lat': 37.537603,
#    'lon': 127.141711,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양토양록농협',
#     'name:en': 'Korea Yangtoyangnok Nonghyup',
#     'name:ko': '한국양토양록농협',
#     'name:ko-Latn': 'Hangukyangtoyangnongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639340,
#    'lat': 37.547542,
#    'lon': 127.133007,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울경기양돈농협',
#     'name:en': 'Seoul Gyeonggiyangdon Nonghyup',
#     'name:ko': '서울경기양돈농협',
#     'name:ko-Latn': 'Seoulgyeonggiyangdonnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639354,
#    'lat': 37.528109,
#    'lon': 126.843841,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양토양록농협',
#     'name:en': 'Korea Yangtoyangnok Nonghyup',
#     'name:ko': '한국양토양록농협',
#     'name:ko-Latn': 'Hangukyangtoyangnongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639361,
#    'lat': 37.547362,
#    'lon': 127.132975,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울경기양돈농협',
#     'name:en': 'Seoul Gyeonggiyangdon Nonghyup',
#     'name:ko': '서울경기양돈농협',
#     'name:ko-Latn': 'Seoulgyeonggiyangdonnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639373,
#    'lat': 37.5349234,
#    'lon': 127.1456571,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양토양록농협',
#     'name:en': 'Korea Yangtoyangnok Nonghyup',
#     'name:ko': '한국양토양록농협',
#     'name:ko-Latn': 'Hangukyangtoyangnongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639384,
#    'lat': 37.57318,
#    'lon': 127.057669,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울경기양돈농협',
#     'name:en': 'Seoul Gyeonggiyangdon Nonghyup',
#     'name:ko': '서울경기양돈농협',
#     'name:ko-Latn': 'Seoulgyeonggiyangdonnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639391,
#    'lat': 37.613237,
#    'lon': 127.034396,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양토양록농협',
#     'name:en': 'Korea Yangtoyangnok Nonghyup',
#     'name:ko': '한국양토양록농협',
#     'name:ko-Latn': 'Hangukyangtoyangnongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639412,
#    'lat': 37.612389,
#    'lon': 127.027734,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울경기양돈농협',
#     'name:en': 'Seoul Gyeonggiyangdon Nonghyup',
#     'name:ko': '서울경기양돈농협',
#     'name:ko-Latn': 'Seoulgyeonggiyangdonnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639421,
#    'lat': 37.64649,
#    'lon': 127.019233,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울경기양돈농협',
#     'name:en': 'Seoul Gyeonggiyangdon Nonghyup',
#     'name:ko': '서울경기양돈농협',
#     'name:ko-Latn': 'Seoulgyeonggiyangdonnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639444,
#    'lat': 37.581184,
#    'lon': 127.085446,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국양계농협',
#     'name:en': 'Korea Yanggye Nonghyup',
#     'name:ko': '한국양계농협',
#     'name:ko-Latn': 'Hangukyanggyenonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639456,
#    'lat': 37.462228,
#    'lon': 127.052696,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서경분화농협',
#     'name:en': 'Seogyeongbunhwa Nonghyup',
#     'name:ko': '서경분화농협',
#     'name:ko-Latn': 'Seogyeongbunhwanonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639469,
#    'lat': 37.558338,
#    'lon': 126.980555,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국화훼농협',
#     'name:en': 'Korea Hwahwe Nonghyup',
#     'name:ko': '한국화훼농협',
#     'name:ko-Latn': 'Hangukhwahwenonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639481,
#    'lat': 37.565826,
#    'lon': 126.986713,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '아우내농협',
#     'name:en': 'Aunae Nonghyup',
#     'name:ja': 'アウネ農協',
#     'name:ko': '아우내농협',
#     'name:ko-Latn': 'Aunaenonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639491,
#    'lat': 37.593967,
#    'lon': 126.947397,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '고창농협',
#     'name:en': 'Gochang Nonghyup',
#     'name:ko': '고창농협',
#     'name:ko-Latn': 'Gochangnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639512,
#    'lat': 37.498984,
#    'lon': 126.923022,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '갈산농협',
#     'name:en': 'Galsan Nonghyup',
#     'name:ko': '갈산농협',
#     'name:ko-Latn': 'Galsannonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639562,
#    'lat': 37.487345,
#    'lon': 126.981349,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '남서울농협',
#     'name:en': 'Nam Seoul Nonghyup',
#     'name:ko': '남서울농협',
#     'name:ko-Latn': 'Namseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639575,
#    'lat': 37.5844521,
#    'lon': 127.0373645,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '개성인삼농협',
#     'name:en': 'Gaeseonginsam Nonghyup',
#     'name:ko': '개성인삼농협',
#     'name:ko-Latn': 'Gaeseonginsamnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639582,
#    'lat': 37.4912019,
#    'lon': 127.088323,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '수서농협',
#     'name:en': 'Suseo Nonghyup',
#     'name:ko': '수서농협',
#     'name:ko-Latn': 'Suseononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639594,
#    'lat': 37.5488721,
#    'lon': 127.136072,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '강동농협',
#     'name:en': 'Gangdong Nonghyup',
#     'name:ko': '강동농협',
#     'name:ko-Latn': 'Gangdongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639621,
#    'lat': 37.5524196,
#    'lon': 126.8365338,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '강서농협',
#     'name:en': 'Gangseo Nonghyup',
#     'name:ko': '강서농협',
#     'name:ko-Latn': 'Gangseononghyeop',
#     'name:zh': '江西农协',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639627,
#    'lat': 37.564346,
#    'lon': 126.908555,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '성산농협',
#     'name:en': 'Seongsan Nonghyup',
#     'name:ko': '성산농협',
#     'name:ko-Latn': 'Seongsannonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639660,
#    'lat': 37.569109,
#    'lon': 126.840989,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'check_date': '2023-09-24',
#     'name': '강서농협',
#     'name:en': 'Gangseo Nonghyup',
#     'name:ko': '강서농협',
#     'name:ko-Latn': 'Gangseononghyeop'}},
#   {'type': 'node',
#    'id': 368639670,
#    'lat': 37.492571,
#    'lon': 127.090812,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '수서농협',
#     'name:en': 'Suseo Nonghyup',
#     'name:ja': '水西農協',
#     'name:ko': '수서농협',
#     'name:ko-Latn': 'Suseononghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639694,
#    'lat': 37.4976348,
#    'lon': 127.1473813,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '송파농협',
#     'name:en': 'Songpa Nonghyup',
#     'name:ko': '송파농협',
#     'name:ko-Latn': 'Songpanonghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639714,
#    'lat': 37.593502,
#    'lon': 126.9184805,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서부농협',
#     'name:en': 'Seobu Nonghyup',
#     'name:ko': '서부농협',
#     'name:ko-Latn': 'Seobunonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639725,
#    'lat': 37.528803,
#    'lon': 127.120245,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '성내농협',
#     'name:en': 'Seongnae Nonghyup',
#     'name:ko': '성내농협',
#     'name:ko-Latn': 'Seongnaenonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639735,
#    'lat': 37.481963,
#    'lon': 126.972817,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '남서울농협',
#     'name:en': 'Nam Seoul Nonghyup',
#     'name:ko': '남서울농협',
#     'name:ko-Latn': 'Namseoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639762,
#    'lat': 37.500669,
#    'lon': 126.844637,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '강원생약농협',
#     'name:en': 'Gangwonsaengyak Nonghyup',
#     'name:ko': '강원생약농협',
#     'name:ko-Latn': 'Gangwonsaengyangnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639781,
#    'lat': 37.5278591,
#    'lon': 126.8978221,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '서울농협',
#     'name:en': 'Seoul Nonghyup',
#     'name:ko': '서울농협',
#     'name:ko-Latn': 'Seoullonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639794,
#    'lat': 37.478754,
#    'lon': 126.931012,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '공덕농협',
#     'name:en': 'Gongdeok Nonghyup',
#     'name:ko': '공덕농협',
#     'name:ko-Latn': 'Gongdeongnonghyeop',
#     'ncat': '농협',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639819,
#    'lat': 37.556964,
#    'lon': 126.943118,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '보성농협',
#     'name:en': 'Boseong Nonghyup',
#     'name:ko': '보성농협',
#     'name:ko-Latn': 'Boseongnonghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368639831,
#    'lat': 37.4961139,
#    'lon': 127.1506842,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '부귀농협',
#     'name:en': 'Bugwi Nonghyup',
#     'name:ko': '부귀농협',
#     'name:ko-Latn': 'Bugwinonghyeop',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368655057,
#    'lat': 37.5417302,
#    'lon': 126.9617237,
#    'tags': {'addr:city': '서울특별시',
#     'addr:district': '용산구',
#     'addr:housenumber': '8',
#     'addr:street': '효창원로69길',
#     'amenity': 'bank',
#     'atm': 'yes',
#     'name': '효창새마을금고 본점',
#     'name:en': 'Saemaul Bank Hyochang Branch',
#     'name:ko': '효창새마을금고 본점',
#     'name:ko-Latn': 'Hyochangdongsaemaeulmungo',
#     'ncat': '도서관',
#     'phone': '+82 02-713-3287',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368894183,
#    'lat': 37.5629343,
#    'lon': 126.9759298,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '중국공상은행',
#     'name:en': 'Junggukgongsang Bank',
#     'name:ja': '中国工商銀行',
#     'name:ko': '중국공상은행',
#     'name:ko-Latn': 'Junggukgongsangeunhaeng',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368894190,
#    'lat': 37.5040678,
#    'lon': 127.0464412,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '더케이저축은행',
#     'name:en': 'Gyowonnara Mutual Saving Bank',
#     'name:ko': '더케이저축은행',
#     'name:ko-Latn': 'Gyowonnarasanghojeochukeunhaeng',
#     'ncat': '은행',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368894198,
#    'lat': 37.568572,
#    'lon': 126.980132,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '한국씨티은행',
#     'name:en': 'Citybank',
#     'name:ja': '韓国シティ銀行',
#     'name:ko': '한국씨티은행',
#     'name:ko-Latn': 'Hangukssitieunhaeng',
#     'ncat': '은행',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 368939445,
#    'lat': 37.654622,
#    'lon': 127.0455367,
#    'tags': {'amenity': 'bank',
#     'brand': '농협',
#     'brand:ko': '농협',
#     'brand:wikidata': 'Q15283673',
#     'name': '농협',
#     'name:en': 'Nonghyup Bank',
#     'name:ko': '농협',
#     'name:ko-Latn': 'Nonghyeop',
#     'ncat': '축협',
#     'operator': '양주축산농협 창동역지점',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 490631690,
#    'lat': 37.5734546,
#    'lon': 127.0460831,
#    'tags': {'amenity': 'atm', 'operator': 'Shinhan Bank'}},
#   {'type': 'node',
#    'id': 870585691,
#    'lat': 37.535315,
#    'lon': 127.144713,
#    'tags': {'amenity': 'bank',
#     'brand': 'KB국민은행',
#     'brand:en': 'KB Kookmin Bank',
#     'brand:ko': 'KB국민은행',
#     'brand:wikidata': 'Q496606',
#     'name': 'KB국민은행',
#     'name:en': 'KB Kookmin Bank',
#     'name:ko': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 931559809,
#    'lat': 37.4647678,
#    'lon': 127.0429482,
#    'tags': {'amenity': 'bank',
#     'brand': '신한은행',
#     'brand:en': 'Sinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'brand:wikipedia': 'en:Shinhan Bank',
#     'name': '신한은행',
#     'name:en': 'Sinhan Bank',
#     'name:ko': '신한은행',
#     'operator': '신한은행'}},
#   {'type': 'node',
#    'id': 939007756,
#    'lat': 37.4645516,
#    'lon': 127.0431823,
#    'tags': {'amenity': 'bank', 'name': 'KEB하나은행', 'operator': '외환은행'}},
#   {'type': 'node',
#    'id': 1654337213,
#    'lat': 37.5413928,
#    'lon': 126.8403933,
#    'tags': {'amenity': 'bank', 'name': '국민은행ATM', 'name:zh': '国民银行ATM'}},
#   {'type': 'node',
#    'id': 1669628093,
#    'lat': 37.6186338,
#    'lon': 126.9211957,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'name': '신한은행',
#     'name:en': 'Shinhan Bank',
#     'name:ko': '신한은행',
#     'name:ko-Latn': 'Shinhan eunhaeng'}},
#   {'type': 'node',
#    'id': 1778799890,
#    'lat': 37.4918865,
#    'lon': 126.9241676,
#    'tags': {'amenity': 'bank',
#     'brand': '농협',
#     'brand:en': 'NH',
#     'brand:ko': '농협',
#     'brand:wikidata': 'Q15283673',
#     'brand:wikipedia': 'ko:NH농협은행',
#     'name': '농협',
#     'name:en': 'Nonghyup Bank',
#     'name:ja': '農協',
#     'name:ko': '농협',
#     'name:ko-Latn': 'Nonghyeop'}},
#   {'type': 'node',
#    'id': 1778799895,
#    'lat': 37.4924015,
#    'lon': 126.9238886,
#    'tags': {'amenity': 'atm', 'fee': 'ATM', 'operator': 'ATM'}},
#   {'type': 'node',
#    'id': 1778799896,
#    'lat': 37.4914013,
#    'lon': 126.9243017,
#    'tags': {'amenity': 'bank',
#     'brand': '하나은행',
#     'brand:en': 'KEB Hana Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'name': '하나은행',
#     'name:en': 'KEB Hana Bank',
#     'name:ja': 'KEBハナ銀行',
#     'name:ko': '하나은행'}},
#   {'type': 'node',
#    'id': 1778799898,
#    'lat': 37.4910523,
#    'lon': 126.9246879,
#    'tags': {'amenity': 'bank',
#     'brand': 'KB국민은행',
#     'brand:en': 'KB Kookmin Bank',
#     'brand:ko': 'KB국민은행',
#     'brand:wikidata': 'Q496606',
#     'name': 'KB국민은행',
#     'name:en': 'KB Kookmin Bank',
#     'name:ja': '国民銀行',
#     'name:ko': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 1786105482,
#    'lat': 37.5837065,
#    'lon': 126.9491274,
#    'tags': {'amenity': 'bank', 'operator': '우리은행 무악제 지점'}},
#   {'type': 'node',
#    'id': 1790475164,
#    'lat': 37.4609151,
#    'lon': 126.9532999,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 1795294178,
#    'lat': 37.6163014,
#    'lon': 127.0642904,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': '농협',
#     'brand:ko': '농협',
#     'brand:wikidata': 'Q15283673',
#     'int_name': 'NongHyup',
#     'name': '농협',
#     'name:en': 'Nonghyup Bank',
#     'name:ja': '農協',
#     'name:ko': '농협',
#     'name:ko-Latn': 'Nonghyeop'}},
#   {'type': 'node',
#    'id': 1795354210,
#    'lat': 37.6169468,
#    'lon': 127.0628686,
#    'tags': {'amenity': 'atm',
#     'fee': '우리은행ATM(Woori Bank ATM)',
#     'operator': '우리은행ATM(Woori Bank ATM)'}},
#   {'type': 'node',
#    'id': 1808686437,
#    'lat': 37.5227174,
#    'lon': 126.9780283,
#    'tags': {'amenity': 'atm',
#     'check_date': '2024-04-17',
#     'name': 'NH농협은행 365코너 국립중앙박물관출장소',
#     'name:en': 'NH Bank National Museum of Korea Branch',
#     'name:ko': 'NH농협은행 365코너 국립중앙박물관출장소',
#     'operator': 'NH Bank'}},
#   {'type': 'node',
#    'id': 1833781707,
#    'lat': 37.5830538,
#    'lon': 126.9480915,
#    'tags': {'amenity': 'atm', 'operator': '우리은행'}},
#   {'type': 'node',
#    'id': 1839883083,
#    'lat': 37.5067899,
#    'lon': 127.0948239,
#    'tags': {'amenity': 'bank', 'name': '한국씨티은행 잠실중앙지점'}},
#   {'type': 'node',
#    'id': 1872149134,
#    'lat': 37.4989623,
#    'lon': 127.0323218,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': '하나은행',
#     'brand:en': 'KEB Hana Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'name': '하나은행',
#     'name:en': 'KEB Hana Bank',
#     'name:ja': 'KEBハナ銀行',
#     'name:ko': '하나은행'}},
#   {'type': 'node',
#    'id': 1872149138,
#    'lat': 37.4987964,
#    'lon': 127.0314219,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': 'KB국민은행',
#     'brand:en': 'KB Kookmin Bank',
#     'brand:ko': 'KB국민은행',
#     'brand:wikidata': 'Q496606',
#     'name': 'KB국민은행',
#     'name:en': 'KB Kookmin Bank',
#     'name:ja': '国民銀行',
#     'name:ko': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 1924627749,
#    'lat': 37.4849404,
#    'lon': 126.8976453,
#    'tags': {'amenity': 'bank',
#     'branch': '구로벤처센터지점',
#     'brand': 'KB국민은행',
#     'brand:en': 'KB Kookmin Bank',
#     'brand:ko': 'KB국민은행',
#     'brand:wikidata': 'Q496606',
#     'name': 'KB국민은행',
#     'name:en': 'KB Kookmin Bank',
#     'name:ko': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 1925380567,
#    'lat': 37.4920442,
#    'lon': 127.0573092,
#    'tags': {'amenity': 'bank',
#     'brand': '국민은행',
#     'brand:en': 'KB Kookmin Bank',
#     'brand:ko': '국민은행',
#     'brand:wikidata': 'Q496606',
#     'brand:wikipedia': 'en:KB Financial Group Inc',
#     'name': '국민은행',
#     'name:en': 'KB Kookmin Bank',
#     'name:ko': '국민은행'}},
#   {'type': 'node',
#    'id': 1925380621,
#    'lat': 37.4906043,
#    'lon': 127.0558317,
#    'tags': {'amenity': 'bank',
#     'brand': '신한은행',
#     'brand:en': 'Sinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'brand:wikipedia': 'en:Shinhan Bank',
#     'name': '신한은행',
#     'name:en': 'Sinhan Bank',
#     'name:ko': '신한은행'}},
#   {'type': 'node',
#    'id': 1925380644,
#    'lat': 37.4913767,
#    'lon': 127.0556759,
#    'tags': {'amenity': 'bank',
#     'brand': '신한은행',
#     'brand:en': 'Sinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'brand:wikipedia': 'en:Shinhan Bank',
#     'name': '신한은행',
#     'name:en': 'Sinhan Bank',
#     'name:ko': '신한은행'}},
#   {'type': 'node',
#    'id': 1925380651,
#    'lat': 37.4909089,
#    'lon': 127.056285,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': '씨티은행',
#     'name:en': 'City Bank'}},
#   {'type': 'node',
#    'id': 1925380707,
#    'lat': 37.4926324,
#    'lon': 127.0585712,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 1925407801,
#    'lat': 37.4741713,
#    'lon': 127.031071,
#    'tags': {'amenity': 'atm', 'operator': '우리은행'}},
#   {'type': 'node',
#    'id': 1925407870,
#    'lat': 37.4831459,
#    'lon': 127.0040124,
#    'tags': {'amenity': 'bank',
#     'name': '씨티은행 (City Bank)',
#     'name:en': 'City Bank',
#     'name:ko': '씨티은행'}},
#   {'type': 'node',
#    'id': 1925407872,
#    'lat': 37.4994172,
#    'lon': 127.0263113,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행',
#     'operator': '우리은행'}},
#   {'type': 'node',
#    'id': 1925419738,
#    'lat': 37.4888022,
#    'lon': 127.051696,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'name': '우리은행 도곡스위트지점',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행 도곡스위트지점'}},
#   {'type': 'node',
#    'id': 1930543879,
#    'lat': 37.4954175,
#    'lon': 127.0527259,
#    'tags': {'amenity': 'bank', 'atm': 'yes', 'name': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 1930544083,
#    'lat': 37.4959366,
#    'lon': 127.0527608,
#    'tags': {'amenity': 'bank', 'atm': 'yes', 'name': '신한은행'}},
#   {'type': 'node',
#    'id': 1930544085,
#    'lat': 37.4953834,
#    'lon': 127.0528942,
#    'tags': {'amenity': 'bank', 'atm': 'yes', 'name': '우리은행'}},
#   {'type': 'node',
#    'id': 1934102899,
#    'lat': 37.5861437,
#    'lon': 127.0323023,
#    'tags': {'addr:city': '서울특별시',
#     'addr:district': '성북구',
#     'addr:housenumber': '119',
#     'addr:street': '안암로',
#     'amenity': 'bank',
#     'brand': '기업은행',
#     'brand:en': 'Industrial Bank of Korea',
#     'brand:ko': '기업은행',
#     'brand:wikidata': 'Q483855',
#     'brand:wikipedia': 'en:Industrial Bank of Korea',
#     'name': '기업은행',
#     'name:en': 'Industrial Bank of Korea',
#     'name:ko': '기업은행'}},
#   {'type': 'node',
#    'id': 1957644494,
#    'lat': 37.5571052,
#    'lon': 127.0789398,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'branch': '군자역지점',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'int_name': 'Woori bank',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행',
#     'name:zh': '友利银行'}},
#   {'type': 'node',
#    'id': 1981019409,
#    'lat': 37.55727,
#    'lon': 127.0436689,
#    'tags': {'amenity': 'atm',
#     'brand': 'KB국민은행',
#     'brand:en': 'KB Kookmin Bank',
#     'brand:ko': 'KB국민은행',
#     'brand:wikidata': 'Q496606',
#     'name': 'KB국민은행',
#     'name:en': 'KB Kookmin Bank',
#     'name:ja': '国民 銀行',
#     'name:ko': 'KB국민은행',
#     'operator': 'KB국민은행',
#     'operator:wikidata': 'Q496606'}},
#   {'type': 'node',
#    'id': 1981019483,
#    'lat': 37.5572996,
#    'lon': 127.0437334,
#    'tags': {'amenity': 'atm',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'name': '신한은행',
#     'name:en': 'Shinhan Bank',
#     'name:ja': '新韓 銀行',
#     'name:ko': '신한은행',
#     'operator': '신한은행',
#     'operator:wikidata': 'Q487230'}},
#   {'type': 'node',
#    'id': 2003977576,
#    'lat': 37.5566996,
#    'lon': 127.0467119,
#    'tags': {'amenity': 'atm', 'operator': '신한은행'}},
#   {'type': 'node',
#    'id': 2102376905,
#    'lat': 37.4667486,
#    'lon': 127.1093431,
#    'tags': {'amenity': 'bank', 'name': '송파농협 세곡동지점'}},
#   {'type': 'node',
#    'id': 2102376910,
#    'lat': 37.4640935,
#    'lon': 127.107294,
#    'tags': {'amenity': 'bank', 'name': '대왕새마을금고', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2102376951,
#    'lat': 37.4872172,
#    'lon': 127.1027127,
#    'tags': {'amenity': 'bank',
#     'branch': '수서역지점',
#     'brand': 'KB국민은행',
#     'brand:en': 'KB Kookmin Bank',
#     'brand:ko': 'KB국민은행',
#     'brand:wikidata': 'Q496606',
#     'name': 'KB국민은행',
#     'name:en': 'KB Kookmin Bank',
#     'name:ja': '国民銀行 水西駅支店',
#     'name:ko': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 2102376975,
#    'lat': 37.4879493,
#    'lon': 127.1026269,
#    'tags': {'amenity': 'bank',
#     'branch': '수서역지점',
#     'brand': 'IBK기업은행',
#     'brand:en': 'Industrial Bank of Korea',
#     'brand:ko': 'IBK기업은행',
#     'brand:wikidata': 'Q483855',
#     'name': 'IBK기업은행',
#     'name:en': 'Industrial Bank of Korea',
#     'name:ko': 'IBK기업은행'}},
#   {'type': 'node',
#    'id': 2102376979,
#    'lat': 37.488392,
#    'lon': 127.1019188,
#    'tags': {'amenity': 'bank',
#     'name': 'KEB하나은행 수서역지점',
#     'name:ja': 'KEBハナ銀行 水西駅支店'}},
#   {'type': 'node',
#    'id': 2102376980,
#    'lat': 37.4878131,
#    'lon': 127.1021119,
#    'tags': {'amenity': 'bank',
#     'branch': '수서역지점',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ja': 'ウリ銀行 水西駅支店',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 2102376981,
#    'lat': 37.4853783,
#    'lon': 127.0980296,
#    'tags': {'amenity': 'bank', 'name': '송파농협 수서동지점'}},
#   {'type': 'node',
#    'id': 2102376991,
#    'lat': 37.4838288,
#    'lon': 127.0835081,
#    'tags': {'amenity': 'bank', 'name': '신한은행 일원역지점'}},
#   {'type': 'node',
#    'id': 2102376996,
#    'lat': 37.4829659,
#    'lon': 127.0800774,
#    'tags': {'amenity': 'bank', 'name': '우리은행 일원역지점'}},
#   {'type': 'node',
#    'id': 2102377017,
#    'lat': 37.4846148,
#    'lon': 127.0851079,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'name': 'KEB외환은행 일원역지점',
#     'opening_hours': '09:00 ~ 16:00'}},
#   {'type': 'node',
#    'id': 2102377155,
#    'lat': 37.4857775,
#    'lon': 127.083507,
#    'tags': {'amenity': 'bank', 'name': '국민은행 일원역지점'}},
#   {'type': 'node',
#    'id': 2102377156,
#    'lat': 37.488409,
#    'lon': 127.0854178,
#    'tags': {'amenity': 'bank',
#     'name': '신한은행 삼성서울병원지점',
#     'name:en': 'Shinhan Bank - SMC'}},
#   {'type': 'node',
#    'id': 2102377734,
#    'lat': 37.4913781,
#    'lon': 127.0882747,
#    'tags': {'amenity': 'bank', 'atm': 'yes', 'name': '우리은행 일원1동지점'}},
#   {'type': 'node',
#    'id': 2102377735,
#    'lat': 37.4920696,
#    'lon': 127.0873919,
#    'tags': {'amenity': 'bank', 'name': '대왕새마을금고 제1분소'}},
#   {'type': 'node',
#    'id': 2102377747,
#    'lat': 37.4937905,
#    'lon': 127.0788142,
#    'tags': {'amenity': 'bank',
#     'branch': '서울주택도시공사금융센터',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 2102378158,
#    'lat': 37.4884808,
#    'lon': 127.0725015,
#    'tags': {'amenity': 'bank', 'name': '하나은행 개포사랑지점'}},
#   {'type': 'node',
#    'id': 2102379254,
#    'lat': 37.489056,
#    'lon': 127.0676938,
#    'tags': {'amenity': 'bank', 'name': '남서울신용협동조합'}},
#   {'type': 'node',
#    'id': 2102379255,
#    'lat': 37.4888176,
#    'lon': 127.0665566,
#    'tags': {'amenity': 'bank', 'name': '산업은행 개포지점'}},
#   {'type': 'node',
#    'id': 2102379256,
#    'lat': 37.4891411,
#    'lon': 127.0690242,
#    'tags': {'amenity': 'bank', 'name': '신한은행 개포동역지점'}},
#   {'type': 'node',
#    'id': 2102379258,
#    'lat': 37.4891013,
#    'lon': 127.0671473,
#    'tags': {'amenity': 'bank', 'name': '우리은행 개포동역지점'}},
#   {'type': 'node',
#    'id': 2102380319,
#    'lat': 37.4787035,
#    'lon': 127.047309,
#    'tags': {'amenity': 'bank', 'name': '국민은행 개포남지점'}},
#   {'type': 'node',
#    'id': 2102380320,
#    'lat': 37.4716193,
#    'lon': 127.0524803,
#    'tags': {'amenity': 'bank', 'name': '능인불교선양원신용협동조합'}},
#   {'type': 'node',
#    'id': 2102380322,
#    'lat': 37.480815,
#    'lon': 127.0530168,
#    'tags': {'amenity': 'bank', 'name': '우리은행 개포중앙지점'}},
#   {'type': 'node',
#    'id': 2102380323,
#    'lat': 37.4826176,
#    'lon': 127.0555708,
#    'tags': {'amenity': 'bank', 'name': 'KEB하나은행(구.외환) 개포로지점'}},
#   {'type': 'node',
#    'id': 2102380327,
#    'lat': 37.4838248,
#    'lon': 127.0569727,
#    'tags': {'amenity': 'bank', 'name': '신한은행 개포남지점'}},
#   {'type': 'node',
#    'id': 2102380328,
#    'lat': 37.4723857,
#    'lon': 127.052137,
#    'tags': {'amenity': 'bank', 'name': '새마을금고 개인택시운송조합 강남지점'}},
#   {'type': 'node',
#    'id': 2102380329,
#    'lat': 37.4810804,
#    'lon': 127.0533018,
#    'tags': {'amenity': 'bank', 'name': 'KEB하나은행(구.하나) 개포동지점'}},
#   {'type': 'node',
#    'id': 2102380330,
#    'lat': 37.4826205,
#    'lon': 127.0608751,
#    'tags': {'amenity': 'bank', 'name': '농협 개포지점'}},
#   {'type': 'node',
#    'id': 2102380439,
#    'lat': 37.4786183,
#    'lon': 127.0448843,
#    'tags': {'amenity': 'bank', 'name': '농협 개포동지점'}},
#   {'type': 'node',
#    'id': 2102380440,
#    'lat': 37.4779883,
#    'lon': 127.0445839,
#    'tags': {'amenity': 'bank', 'name': '외환은행 포이동지점'}},
#   {'type': 'node',
#    'id': 2102380452,
#    'lat': 37.4853272,
#    'lon': 127.0459143,
#    'tags': {'amenity': 'bank', 'name': '국민은행 매봉역지점'}},
#   {'type': 'node',
#    'id': 2102380519,
#    'lat': 37.4877755,
#    'lon': 127.04962,
#    'tags': {'amenity': 'bank', 'name': '우리은행 개포동지점'}},
#   {'type': 'node',
#    'id': 2102380976,
#    'lat': 37.4887325,
#    'lon': 127.0535532,
#    'tags': {'amenity': 'bank',
#     'brand': '신한은행',
#     'brand:en': 'Sinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'brand:wikipedia': 'en:Shinhan Bank',
#     'name': '신한은행',
#     'name:en': 'Sinhan Bank',
#     'name:ko': '신한은행'}},
#   {'type': 'node',
#    'id': 2102380977,
#    'lat': 37.4889368,
#    'lon': 127.0531026,
#    'tags': {'amenity': 'bank', 'name': '산업은행 도곡지점'}},
#   {'type': 'node',
#    'id': 2102380978,
#    'lat': 37.48668,
#    'lon': 127.0517347,
#    'tags': {'amenity': 'bank', 'name': '국민은행 도곡중앙지점'}},
#   {'type': 'node',
#    'id': 2102380980,
#    'lat': 37.4884172,
#    'lon': 127.0513567,
#    'tags': {'amenity': 'bank', 'name': '하나은행 도곡역지점'}},
#   {'type': 'node',
#    'id': 2102380981,
#    'lat': 37.4833351,
#    'lon': 127.0469442,
#    'tags': {'amenity': 'bank', 'name': '우리은행 송파북지점'}},
#   {'type': 'node',
#    'id': 2102380983,
#    'lat': 37.4868543,
#    'lon': 127.0510854,
#    'tags': {'amenity': 'bank', 'name': '기업은행 도곡팰리스지점'}},
#   {'type': 'node',
#    'id': 2102380992,
#    'lat': 37.4905543,
#    'lon': 127.0572654,
#    'tags': {'amenity': 'bank', 'name': '신한은행도곡역지점'}},
#   {'type': 'node',
#    'id': 2102386073,
#    'lat': 37.4929378,
#    'lon': 127.0461288,
#    'tags': {'amenity': 'bank',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
# ...
#     'brand': 'KB국민은행',
#     'brand:en': 'KB Kookmin Bank',
#     'brand:ko': 'KB국민은행',
#     'brand:wikidata': 'Q496606',
#     'name': 'KB국민은행',
#     'name:en': 'KB Kookmin Bank',
#     'name:ko': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 6277962191,
#    'lat': 37.4954291,
#    'lon': 126.8888549,
#    'tags': {'amenity': 'bank',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'name': '신한은행',
#     'name:en': 'Shinhan Bank',
#     'name:ko': '신한은행'}},
#   {'type': 'node',
#    'id': 6448944985,
#    'lat': 37.5643648,
#    'lon': 126.9866206,
#    'tags': {'amenity': 'atm'}},
#   {'type': 'node',
#    'id': 6451244588,
#    'lat': 37.5134099,
#    'lon': 126.9432789,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'brand': '하나은행',
#     'brand:en': 'Korea Exchange Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'brand:wikipedia': 'en:Korea Exchange Bank',
#     'drive_through': 'no',
#     'name': '하나은행',
#     'name:en': 'Korea Exchange Bank',
#     'name:ko': '하나은행',
#     'operator': 'yes'}},
#   {'type': 'node',
#    'id': 6480737169,
#    'lat': 37.549547,
#    'lon': 126.8217086,
#    'tags': {'amenity': 'atm', 'drive_through': 'no', 'operator': 'VAN사'}},
#   {'type': 'node',
#    'id': 6485202351,
#    'lat': 37.5562811,
#    'lon': 126.9223307,
#    'tags': {'amenity': 'bank',
#     'brand': '하나은행',
#     'brand:en': 'KEB Hana Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'brand:wikipedia': 'en:Hana Bank',
#     'name': '하나은행',
#     'name:en': 'KEB Hana Bank',
#     'name:ja': 'ハナ銀行',
#     'name:ko': '하나은행'}},
#   {'type': 'node',
#    'id': 6485257907,
#    'lat': 37.5537609,
#    'lon': 126.9189766,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'branch': '서교중앙지점',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'brand:wikipedia': 'en:Shinhan Bank',
#     'name': '신한은행',
#     'name:en': 'Shinhan Bank',
#     'name:ko': '신한은행'}},
#   {'type': 'node',
#    'id': 6555168686,
#    'lat': 37.516872,
#    'lon': 127.019684,
#    'tags': {'amenity': 'bank',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 6586943228,
#    'lat': 37.5694602,
#    'lon': 126.9174737,
#    'tags': {'amenity': 'bank',
#     'brand': '농협',
#     'brand:en': 'NH',
#     'brand:ko': '농협',
#     'brand:wikidata': 'Q15283673',
#     'brand:wikipedia': 'ko:NH농협은행',
#     'name': '농협',
#     'name:en': 'Nonghyup Bank',
#     'name:ja': '農協',
#     'name:ko': '농협',
#     'name:ko-Latn': 'Nonghyeop'}},
#   {'type': 'node',
#    'id': 6592886378,
#    'lat': 37.4849838,
#    'lon': 127.1222629,
#    'tags': {'addr:city': '서울특별시',
#     'addr:district': '송파구',
#     'addr:postcode': '05854',
#     'addr:street': '송파대로 167',
#     'amenity': 'bank',
#     'name': '지인시스템',
#     'operator': '지인시스템'}},
#   {'type': 'node',
#    'id': 6596253670,
#    'lat': 37.5687618,
#    'lon': 126.9321928,
#    'tags': {'amenity': 'atm',
#     'opening_hours': 'Mo-Su 07:00-23:30',
#     'operator': 'Woori Bank'}},
#   {'type': 'node',
#    'id': 6598303086,
#    'lat': 37.5255386,
#    'lon': 126.8888256,
#    'tags': {'amenity': 'atm'}},
#   {'type': 'node',
#    'id': 6598945105,
#    'lat': 37.5347983,
#    'lon': 126.9940781,
#    'tags': {'amenity': 'atm',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'name': '신한은행',
#     'name:en': 'Shinhan Bank',
#     'name:ko': '신한은행',
#     'operator': '신한은행',
#     'operator:wikidata': 'Q487230'}},
#   {'type': 'node',
#    'id': 6612489938,
#    'lat': 37.4816447,
#    'lon': 127.1422449,
#    'tags': {'amenity': 'atm',
#     'drive_through': 'no',
#     'level': '1',
#     'operator': '우리은행'}},
#   {'type': 'node',
#    'id': 6687209874,
#    'lat': 37.5629482,
#    'lon': 126.9814999,
#    'tags': {'amenity': 'bank',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 6696365122,
#    'lat': 37.6804269,
#    'lon': 127.0461548,
#    'tags': {'amenity': 'atm',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'cash_in': 'yes',
#     'name': '신한은행 365코너 도봉역',
#     'name:en': 'Shinhan Bank',
#     'name:ko': '신한은행',
#     'operator': '신한은행',
#     'operator:wikidata': 'Q487230'}},
#   {'type': 'node',
#    'id': 6838305762,
#    'lat': 37.680789,
#    'lon': 127.0478098,
#    'tags': {'amenity': 'atm',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'cash_in': 'yes',
#     'drive_through': 'no',
#     'name:en': 'Shinhan Bank',
#     'name:ko': '신한은행',
#     'operator': '신한은행',
#     'operator:wikidata': 'Q487230'}},
#   {'type': 'node',
#    'id': 6867122962,
#    'lat': 37.5139853,
#    'lon': 127.1075839,
#    'tags': {'amenity': 'bank',
#     'brand': 'IBK기업은행',
#     'brand:en': 'Industrial Bank of Korea',
#     'brand:ko': 'IBK기업은행',
#     'brand:wikidata': 'Q483855',
#     'name': 'IBK기업은행',
#     'name:en': 'Industrial Bank of Korea',
#     'name:ko': 'IBK기업은행'}},
#   {'type': 'node',
#    'id': 7060279856,
#    'lat': 37.6116102,
#    'lon': 126.9161496,
#    'tags': {'amenity': 'bank', 'name': '신협'}},
#   {'type': 'node',
#    'id': 7133179726,
#    'lat': 37.5702781,
#    'lon': 126.9137041,
#    'tags': {'amenity': 'bank', 'name': 'KEB'}},
#   {'type': 'node',
#    'id': 7133201171,
#    'lat': 37.5699045,
#    'lon': 126.91437,
#    'tags': {'amenity': 'bank', 'name': 'KB'}},
#   {'type': 'node',
#    'id': 7161990399,
#    'lat': 37.5485513,
#    'lon': 126.916336,
#    'tags': {'amenity': 'bank',
#     'brand': '농협',
#     'brand:en': 'NH',
#     'brand:ko': '농협',
#     'brand:wikidata': 'Q15283673',
#     'brand:wikipedia': 'ko:NH농협은행',
#     'name': '농협',
#     'name:en': 'NH',
#     'name:ko': '농협'}},
#   {'type': 'node',
#    'id': 7173824560,
#    'lat': 37.5641645,
#    'lon': 126.9811008,
#    'tags': {'amenity': 'bank',
#     'brand': '하나은행',
#     'brand:en': 'KEB Hana Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'brand:wikipedia': 'en:Korea Exchange Bank',
#     'name': '하나은행',
#     'name:en': 'KEB Hana Bank',
#     'name:ko': '하나은행'}},
#   {'type': 'node',
#    'id': 7222138756,
#    'lat': 37.5547719,
#    'lon': 127.020141,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'drive_through': 'no',
#     'name': '신한은행 신금호역지점',
#     'name:en': 'Shinhan Bank Singeumho',
#     'operator': '신한은행'}},
#   {'type': 'node',
#    'id': 7222138757,
#    'lat': 37.5540798,
#    'lon': 127.0204658,
#    'tags': {'amenity': 'bank',
#     'atm': 'yes',
#     'drive_through': 'no',
#     'name': '우리은행 365자동화지점',
#     'name:en': 'Woori Bank 365 ATM',
#     'operator': '우리은행'}},
#   {'type': 'node',
#    'id': 7226587284,
#    'lat': 37.5706917,
#    'lon': 126.9126221,
#    'tags': {'amenity': 'bank', 'name': '신한은행'}},
#   {'type': 'node',
#    'id': 7234688743,
#    'lat': 37.524717,
#    'lon': 127.0242757,
#    'tags': {'amenity': 'bank', 'name': '우리은행신압구정지점'}},
#   {'type': 'node',
#    'id': 7319933504,
#    'lat': 37.5593951,
#    'lon': 126.9817703,
#    'tags': {'amenity': 'bank',
#     'branch': 'headquarters',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ja': 'ウリ銀行',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 7326373919,
#    'lat': 37.5609685,
#    'lon': 126.9902979,
#    'tags': {'amenity': 'bank',
#     'brand': '하나은행',
#     'brand:en': 'KEB Hana Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'brand:wikipedia': 'en:Korea Exchange Bank',
#     'name': '하나은행',
#     'name:en': 'KEB Hana Bank',
#     'name:ko': '하나은행'}},
#   {'type': 'node',
#    'id': 7489649890,
#    'lat': 37.5504642,
#    'lon': 127.146209,
#    'tags': {'amenity': 'bank',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'brand:wikipedia': 'en:Shinhan Bank',
#     'name': '신한은행',
#     'name:en': 'Shinhan Bank',
#     'name:ko': '신한은행'}},
#   {'type': 'node',
#    'id': 7489649891,
#    'lat': 37.5504102,
#    'lon': 127.1463134,
#    'tags': {'amenity': 'atm'}},
#   {'type': 'node',
#    'id': 7499844051,
#    'lat': 37.5401839,
#    'lon': 127.0625621,
#    'tags': {'amenity': 'bank',
#     'brand': '기업은행',
#     'brand:en': 'Industrial Bank of Korea',
#     'brand:ko': '기업은행',
#     'brand:wikidata': 'Q483855',
#     'brand:wikipedia': 'en:Industrial Bank of Korea',
#     'name': '기업은행',
#     'name:en': 'Industrial Bank of Korea',
#     'name:ko': '기업은행'}},
#   {'type': 'node',
#    'id': 7499852848,
#    'lat': 37.5419298,
#    'lon': 127.0641552,
#    'tags': {'amenity': 'bank',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 7500183369,
#    'lat': 37.5498254,
#    'lon': 127.1440163,
#    'tags': {'amenity': 'bank',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 7510786585,
#    'lat': 37.5664887,
#    'lon': 126.9925066,
#    'tags': {'amenity': 'bank', 'name': '우리신용정보                   우리은행'}},
#   {'type': 'node',
#    'id': 7515135790,
#    'lat': 37.5301271,
#    'lon': 126.8378411,
#    'tags': {'amenity': 'bank',
#     'branch': '신월동출장소',
#     'brand': '하나은행',
#     'brand:en': 'KEB Hana Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'name': '하나은행',
#     'name:en': 'KEB Hana Bank',
#     'name:ko': '하나은행'}},
#   {'type': 'node',
#    'id': 7518481385,
#    'lat': 37.5816026,
#    'lon': 127.0888215,
#    'tags': {'addr:city': '서울특별시',
#     'addr:district': '중랑구',
#     'addr:housenumber': '332',
#     'addr:postcode': '02213',
#     'addr:street': '면목로',
#     'amenity': 'bank',
#     'brand': 'MG새마을금고',
#     'brand:ko': 'MG새마을금고',
#     'brand:wikidata': 'Q12600614',
#     'name': 'MG새마을금고',
#     'name:ko': 'MG새마을금고'}},
#   {'type': 'node',
#    'id': 7518490685,
#    'lat': 37.5823355,
#    'lon': 127.0886627,
#    'tags': {'amenity': 'bank',
#     'brand': '신한은행',
#     'brand:en': 'Shinhan Bank',
#     'brand:ko': '신한은행',
#     'brand:wikidata': 'Q487230',
#     'name': '신한은행',
#     'name:en': 'Shinhan Bank',
#     'name:ko': '신한은행'}},
#   {'type': 'node',
#    'id': 7524718343,
#    'lat': 37.619723,
#    'lon': 127.0596371,
#    'tags': {'amenity': 'bank',
#     'brand': '하나은행',
#     'brand:en': 'KEB Hana Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'brand:wikipedia': 'en:Korea Exchange Bank',
#     'name': '하나은행',
#     'name:en': 'KEB Hana Bank',
#     'name:ko': '하나은행'}},
#   {'type': 'node',
#    'id': 7529002287,
#    'lat': 37.5637692,
#    'lon': 127.0527871,
#    'tags': {'amenity': 'bank',
#     'brand': 'MG새마을금고',
#     'brand:ko': 'MG새마을금고',
#     'brand:wikidata': 'Q12600614',
#     'name': 'MG새마을금고',
#     'name:ko': 'MG새마을금고',
#     'operator': 'MG새마을금고',
#     'operator:wikidata': 'Q12600614'}},
#   {'type': 'node',
#    'id': 7557517939,
#    'lat': 37.5852011,
#    'lon': 127.0186515,
#    'tags': {'amenity': 'bank', 'name': 'MG새마을금고'}},
#   {'type': 'node',
#    'id': 7557523585,
#    'lat': 37.5661843,
#    'lon': 127.0676872,
#    'tags': {'amenity': 'bank', 'name': '우리은행'}},
#   {'type': 'node',
#    'id': 7557524313,
#    'lat': 37.5620239,
#    'lon': 127.0651696,
#    'tags': {'amenity': 'bank',
#     'brand': 'NH농협은행',
#     'brand:en': 'NH Bank',
#     'brand:ko': 'NH농협은행',
#     'brand:wikidata': 'Q15283673',
#     'name': 'NH농협은행',
#     'name:en': 'NH Bank',
#     'name:ko': 'NH농협은행'}},
#   {'type': 'node',
#    'id': 7557524727,
#    'lat': 37.575349,
#    'lon': 127.0720486,
#    'tags': {'amenity': 'bank', 'name': 'NH농협'}},
#   {'type': 'node',
#    'id': 7557530802,
#    'lat': 37.5723356,
#    'lon': 127.0736173,
#    'tags': {'amenity': 'bank', 'name': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 7557531093,
#    'lat': 37.5882856,
#    'lon': 127.0060706,
#    'tags': {'amenity': 'bank', 'name': 'KEB하나은행'}},
#   {'type': 'node',
#    'id': 7557531094,
#    'lat': 37.5894019,
#    'lon': 127.0053988,
#    'tags': {'amenity': 'bank', 'name': '우리생협'}},
#   {'type': 'node',
#    'id': 7557536846,
#    'lat': 37.5655391,
#    'lon': 127.0173552,
#    'tags': {'amenity': 'bank',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 7557536847,
#    'lat': 37.5655524,
#    'lon': 127.0174744,
#    'tags': {'amenity': 'bank',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'brand:wikipedia': 'en:Woori Bank',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 7557536854,
#    'lat': 37.5927449,
#    'lon': 127.016295,
#    'tags': {'amenity': 'bank',
#     'brand': 'IBK기업은행',
#     'brand:en': 'Industrial Bank of Korea',
#     'brand:ko': 'IBK기업은행',
#     'brand:wikidata': 'Q483855',
#     'name': 'IBK기업은행',
#     'name:en': 'Industrial Bank of Korea',
#     'name:ko': 'IBK기업은행'}},
#   {'type': 'node',
#    'id': 7557537290,
#    'lat': 37.5905378,
#    'lon': 127.0145154,
#    'tags': {'amenity': 'bank',
#     'brand': '우리은행',
#     'brand:en': 'Woori Bank',
#     'brand:ko': '우리은행',
#     'brand:wikidata': 'Q494369',
#     'name': '우리은행',
#     'name:en': 'Woori Bank',
#     'name:ko': '우리은행'}},
#   {'type': 'node',
#    'id': 7557537334,
#    'lat': 37.5927056,
#    'lon': 127.0160447,
#    'tags': {'amenity': 'bank', 'name': '하나투자금융'}},
#   {'type': 'node',
#    'id': 7557542887,
#    'lat': 37.4848212,
#    'lon': 126.8863557,
#    'tags': {'amenity': 'bank',
#     'brand': '하나은행',
#     'brand:en': 'KEB Hana Bank',
#     'brand:ko': '하나은행',
#     'brand:wikidata': 'Q484047',
#     'name': '하나은행',
#     'name:en': 'KEB Hana Bank',
#     'name:ko': '하나은행'}},
#   {'type': 'node',
#    'id': 7558368301,
#    'lat': 37.6113299,
#    'lon': 127.008802,
#    'tags': {'amenity': 'bank', 'name': 'KEB하나은행'}},
#   {'type': 'node',
#    'id': 7558383791,
#    'lat': 37.5937239,
#    'lon': 127.0161975,
#    'tags': {'amenity': 'bank', 'name': 'NH농협365'}},
#   {'type': 'node',
#    'id': 7558391617,
#    'lat': 37.6022798,
#    'lon': 127.0186354,
#    'tags': {'amenity': 'bank', 'name': '신협'}},
#   {'type': 'node',
#    'id': 7558448704,
#    'lat': 37.6043189,
#    'lon': 127.0226096,
#    'tags': {'amenity': 'bank', 'name': 'NH농협은행'}},
#   {'type': 'node',
#    'id': 7558477896,
#    'lat': 37.6046132,
#    'lon': 127.0231446,
#    'tags': {'amenity': 'bank',
#     'brand': '새마을금고',
#     'brand:ko': '새마을금고',
#     'brand:wikidata': 'Q12600614',
#     'brand:wikipedia': 'ko:새마을금고',
#     'name': '성북제일새마을금고 본점',
#     'name:ko': '성북제일새마을금고 본점'}},
#   {'type': 'node',
#    'id': 7558477898,
#    'lat': 37.6028834,
#    'lon': 127.0168588,
#    'tags': {'amenity': 'bank', 'name': 'Mg새마을금고'}},
#   {'type': 'node',
#    'id': 7558553098,
#    'lat': 37.6028384,
#    'lon': 127.0194177,
#    'tags': {'amenity': 'bank',
#     'name': 'KB국민은행',
#     'name:en': 'KB Kookmin Bank'}},
#   {'type': 'node',
#    'id': 7558553108,
#    'lat': 37.4990578,
#    'lon': 126.9335598,
#    'tags': {'amenity': 'bank',
#     'brand': 'IBK기업은행',
#     'brand:en': 'Industrial Bank of Korea',
#     'brand:ko': 'IBK기업은행',
#     'brand:wikidata': 'Q483855',
#     'brand:wikipedia': 'en:Industrial Bank of Korea',
#     'name': 'IBK기업은행',
#     'name:en': 'Industrial Bank of Korea',
#     'name:ko': 'IBK기업은행'}},
#   {'type': 'node',
#    'id': 7558553111,
#    'lat': 37.4990171,
#    'lon': 126.9282238,
#    'tags': {'amenity': 'bank', 'name': 'NH농협'}},
#   {'type': 'node',
#    'id': 7558557393,
#    'lat': 37.5601925,
#    'lon': 127.0136541,
#    'tags': {'amenity': 'bank', 'name': 'KB국민은행'}},
#   {'type': 'node',
#    'id': 7558557398,
#    'lat': 37.6029627,
#    'lon': 127.0132583,
#    'tags': {'amenity': 'bank', 'name': 'Kb국민은행'}},
#   ...]}

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
area(3602297418)->.searchArea; 
// 시설 검색
(
  node["railway"="subway_entrance"](area.searchArea);
  way["railway"="station"]["station"="subway"](area.searchArea);
  relation["railway"="station"]["station"="subway"](area.searchArea);
);
// 결과 출력
out body;

"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()


pois= []
for element in data['elements']:
    # print(element)
    lon = element.get('lon', None)
    lat = element.get('lat', None)
    tags = element.get('tags', None)
    if lon and lat and tags:
        pois.append({
            'geometry': Point(float(lon), float(lat)),
            'name': tags.get('name', tags.get('description', tags.get('description:en',None))),
            'amenity': tags.get('amenity', tags.get('railway', None)),
            'lon' : lon,
            'lat' : lat
        })

pois_gdf = gpd.GeoDataFrame(pois, columns=['geometry', 'name', 'amenity', 'lon', 'lat'])
pois_gdf
# Out:
#                         geometry              name          amenity  \
# 0      POINT (127.0585 37.63435)          월계역 2번출구  subway_entrance
# 1     POINT (127.09973 37.51426)           잠실역7번출구  subway_entrance
# 2     POINT (126.88982 37.51028)              신도림역  subway_entrance
# 3     POINT (127.04869 37.56985)               신답역  subway_entrance
# 4     POINT (127.04324 37.57939)         청량리역 6번출구  subway_entrance
# ...                          ...               ...              ...
# 1828  POINT (127.00266 37.56673)              None  subway_entrance
# 1829   POINT (127.1372 37.55714)              None  subway_entrance
# 1830  POINT (127.13728 37.55695)              None  subway_entrance
# 1831  POINT (127.13834 37.55724)              None  subway_entrance
# 1832  POINT (127.02798 37.58694)  안암역 1번출구 안암병원 통로  subway_entrance
#
#              lon        lat
# 0     127.058500  37.634355
# 1     127.099733  37.514259
# 2     126.889815  37.510279
# 3     127.048690  37.569850
# 4     127.043236  37.579385
# ...          ...        ...
# 1828  127.002662  37.566732
# 1829  127.137204  37.557136
# 1830  127.137276  37.556951
# 1831  127.138336  37.557237
# 1832  127.027975  37.586938
#
# [1833 rows x 5 columns]

# %%
pois_gdf['name'].isnull().sum()
# Out:
# 200

# %%
nodes=data['elements']
nodes[1828]
# Out:
# {'type': 'node',
#  'id': 11953523881,
#  'lat': 37.5667319,
#  'lon': 127.002662,
#  'tags': {'railway': 'subway_entrance', 'ref': '5'}}

# %%
tags_list =  [node['tags'] for node in data['elements'] if 'tags' in node]
lists = [list(item.keys()) for item in tags_list]
lists
# unique_keys = set(key for item in tags_list for key in item.keys())

# # 고유한 키 목록 출력
# print(unique_keys)
# Out:
# [['name', 'name:en', 'name:ja', 'railway', 'route_ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['name', 'name:en', 'name:ko', 'name:ko-Latn', 'ncat', 'railway', 'source'],
#  ['name', 'name:en', 'name:ko', 'name:ko-Latn', 'ncat', 'railway', 'source'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'name:ko-Latn', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['description:en', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['description:en', 'railway', 'ref'],
#  ['description:en', 'railway', 'ref'],
#  ['description:en', 'railway', 'ref'],
#  ['description:en', 'railway', 'ref'],
#  ['description:en', 'railway', 'ref'],
#  ['description:en', 'railway', 'ref'],
#  ['description:en', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:ja', 'railway', 'ref'],
#  ['description', 'description:ja', 'railway', 'ref', 'wheelchair'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'entrance',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'source'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'source'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'source'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'source'],
#  ['description:en', 'name', 'name:ja', 'railway', 'ref'],
#  ['description:en', 'name', 'name:ja', 'railway', 'ref'],
#  ['description:en', 'name', 'name:ja', 'railway', 'ref'],
#  ['description:en', 'name', 'name:ja', 'railway', 'ref'],
#  ['description:en', 'name', 'name:ja', 'railway', 'ref'],
#  ['description:en', 'name', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['description', 'description:en', 'railway', 'ref'],
#  ['description:en', 'name', 'name:ja', 'railway', 'ref'],
#  ['description:en', 'name', 'name:ja', 'railway', 'ref'],
#  ['description',
#   'description:en',
#   'name',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'railway',
#   'ref',
#   'source',
#   'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'railway',
#   'ref',
#   'source',
#   'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'railway',
#   'ref',
#   'source'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'railway',
#   'ref',
#   'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway', 'source'],
#  ['name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'source',
#   'toilets:wheelchair',
#   'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'source'],
#  ['railway', 'ref', 'source', 'wheelchair'],
#  ['railway', 'ref', 'source', 'wheelchair'],
#  ['railway', 'ref', 'source'],
#  ['railway', 'ref', 'source'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'source'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'source'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'source'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['description', 'description:en', 'railway', 'ref', 'source'],
#  ['description', 'description:en', 'railway', 'ref', 'source'],
#  ['railway', 'ref'],
#  ['railway', 'ref', 'source'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['description:en',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description:en', 'name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['description:en', 'name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['description:en', 'name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description', 'description:en', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description', 'description:en', 'railway', 'ref', 'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'railway'],
#  ['name', 'name:en', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'railway', 'ref'],
#  ['description', 'description:en', 'railway', 'ref'],
#  ['description', 'description:en', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ko', 'railway'],
#  ['description',
#   'description:en',
#   'description:ko',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ko',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref',
#   'tourism'],
#  ['description',
#   'description:en',
#   'description:ko',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description', 'description:en', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:ja',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:ja',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:ja',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:ja',
#   'railway',
#   'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['railway', 'ref'],
#  ['name:ja', 'railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['description',
#   'description:en',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['description',
#   'description:en',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'name',
#   'name:en',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:zh', 'railway', 'wheelchair'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:de', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref', 'wheelchair'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name', 'name:en', 'name:ja', 'railway'],
#  ['name',
#   'name:en',
#   'name:ja',
#   'name:zh',
#   'name:zh-Hans',
#   'name:zh-Hant',
#   'railway'],
#  ['name',
#   'name:en',
#   'name:ja',
#   'name:zh',
#   'name:zh-Hans',
#   'name:zh-Hant',
#   'railway'],
#  ['name',
#   'name:en',
#   'name:ja',
#   'name:zh',
#   'name:zh-Hans',
#   'name:zh-Hant',
#   'railway'],
#  ['name',
#   'name:en',
#   'name:ja',
#   'name:zh',
#   'name:zh-Hans',
#   'name:zh-Hant',
#   'railway'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref',
#   'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description',
#   'description:en',
#   'description:ja',
#   'name',
#   'name:en',
#   'name:ja',
#   'name:ko',
#   'railway',
#   'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'description:ja', 'railway', 'ref'],
#  ['description', 'description:en', 'railway', 'ref'],
#  ['description', 'description:en', 'railway', 'ref'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway'],
#  ['railway', 'ref'],
#  ['railway', 'ref'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref'],
#  ['name', 'name:ja', 'name:ko', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'railway', 'ref', 'wheelchair'],
#  ['name', 'name:en', 'name:ja', 'name:ko', 'railway', 'wheelchair'],
#  ...]

# %%
# 각 리스트의 항목을 집합으로 변환하여 중복 항목 계산
all_elements = [item for sublist in lists for item in sublist]
unique_elements = set(item for item in all_elements if all_elements.count(item) == 1)

# 중복되지 않는 항목만 포함하는 리스트 필터링
filtered_lists = []
for sublist in lists:
    filtered_lists.append([item for item in sublist if item in unique_elements])

# 결과 출력
print(filtered_lists)
# Out:
# [['route_ref'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['tourism'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ...

# %%
import requests

# Overpass API URL
overpass_url = "http://overpass-api.de/api/interpreter"

# Area ID로 OSM 데이터를 가져오는 쿼리
overpass_query = """
[out:json];
area(162177234);
out body;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
print(data)
# Out:
# {'version': 0.6, 'generator': 'Overpass API 0.7.62.5 1bd436f1', 'osm3s': {'timestamp_osm_base': '2025-03-20T06:41:59Z', 'timestamp_areas_base': '2025-02-06T02:17:44Z', 'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}, 'elements': [{'type': 'way', 'id': 162177234, 'nodes': [1741105504, 1741105512, 1741105514, 1741105511, 1741105504], 'tags': {'razed:building': 'yes', 'source:geometry:date': '2016-06-09', 'source:geometry:ref': 'Picc/933722'}}]}

# %%
import requests

# Overpass API URL
overpass_url = "http://overpass-api.de/api/interpreter"

# Area ID로 OSM 데이터를 가져오는 쿼리
overpass_query = """
[out:json];
area(2297418);
out body;
"""

# Overpass API 요청 보내기
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# 결과 확인
print(data)
# Out:
# {'version': 0.6, 'generator': 'Overpass API 0.7.62.5 1bd436f1', 'osm3s': {'timestamp_osm_base': '2025-03-20T02:19:34Z', 'timestamp_areas_base': '2025-02-06T02:17:44Z', 'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}, 'elements': []}
